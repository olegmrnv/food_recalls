# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
import csv
import json
import datetime
import time
import pandas as pd

#https://api.fda.gov/food/enforcement.json?search=classification:"Class+III"&limit=1"

url = "https://api.fda.gov/food/enforcement.json?search="

# %%
#year 2019 API Request for product recalls
url_19 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20190101+TO+20191231]&limit=99"
firms_19 = requests.get(url_19).json()
firms_19
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 499}},
#  'results': [{'country': 'United States',
#    'city': 'Austin',
#    'reason_for_recall': 'Product potentially contaminated with Salmonella.',
#    'address_1': '550 Bowie St',
#    'address_2': '',
#    'code_info': '0272681; Sell by Date 1/24/19, 1/26/19, 1/27/19, 1/28/19',
#    'product_quantity': '16 units',
#    'center_classification_date': '20190228',
#    'distribution_pattern': 'Connecticut, Florida, Maine, Massachusetts, New Hampshire, New Jersey, New York, and Rhode Island',
#    'state': 'TX',
# ...

# %%
df = pd.DataFrame(firms_19["results"])

# %%
df.columns
# Out:
# Index(['address_1', 'address_2', 'center_classification_date', 'city',
#        'classification', 'code_info', 'country', 'distribution_pattern',
#        'event_id', 'initial_firm_notification', 'more_code_info', 'openfda',
#        'postal_code', 'product_description', 'product_quantity',
#        'product_type', 'reason_for_recall', 'recall_initiation_date',
#        'recall_number', 'recalling_firm', 'report_date', 'state', 'status',
#        'termination_date', 'voluntary_mandated'],
#       dtype='object')

# %%
df_clean_19 = df[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]

df_clean_19
# Out:
#    state             city report_date  \
# 0     TX           Austin    20190306
# 1     TX           Austin    20190306
# 2     IL          Chicago    20190220
# 3     IA  West des Moines    20190213
# 4     CA   Marina Del Rey    20190220
# 5     WI       Lake Mills    20190220
# 6     NC          Concord    20190227
# 7     CA   Marina Del Rey    20190220
# 8     OH         Columbus    20190102
# 9     NC          Concord    20190227
# 10    CO           Denver    20190227
# 11    CA             Brea    20190206
# 12    NC          Concord    20190227
# 13    NC          Concord    20190227
# 14    WI       Lake Mills    20190220
# 15    GA         Savannah    20190220
# 16    CA    San Francisco    20190320
# 17    WI       Lake Mills    20190220
# 18    OR             Bend    20190306
# 19    IL          Chicago    20190220
# 20    PR           Gurabo    20190313
# 21    ME        Ellsworth    20190410
# 22    WA          Spokane    20190213
# ...

# %%
#csv_name_clean_19 = "FDA_Recall_clean_2019.csv"
#df_clean_19.to_csv(csv_name_clean_19)

# %%
#year 2018 API Request for product recalls
url_18 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20180101+TO+20181231]&limit=99"
firms_18 = requests.get(url_18).json()
firms_18
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 1910}},
#  'results': [{'country': 'United States',
#    'city': 'Minneapolis',
#    'reason_for_recall': 'Shipping container from CA to HI was not held at proper temperature which could cause food items to be contaminated with spoilage organisms or pathogens',
#    'address_1': '33 S 6th St',
#    'address_2': '',
#    'code_info': 'All product purchased at  Target store T2780, Honolulu, HI from March 23 through March 27, 2018.',
#    'product_quantity': '2652 retail units total',
# ...

# %%
df_18 = pd.DataFrame(firms_18["results"])
#csv_name_18 = "FDA_Recall_2018.csv"
#df.to_csv(csv_name_18, index=False)

# %%
df_clean_18 = df_18[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
#csv_name_clean_18 = "FDA_Recall_clean_2018.csv"
#df_clean_18.to_csv(csv_name_clean_18)
df_clean_18
# Out:
#    state              city report_date  \
# 0     MN       Minneapolis    20180509
# 1     CA           Oakland    20180404
# 2     CA  City of Industry    20181219
# 3     PA      Chambersburg    20180124
# 4     MD         Baltimore    20180307
# 5     NY          Brooklyn    20181121
# 6     CA         Inglewood    20180516
# 7     OH             Solon    20180131
# 8     FL             Davie    20180131
# 9     IL             Alsip    20180404
# 10             Maple Ridge    20180516
# 11    WA         Sunnyside    20181114
# 12    IL             Alsip    20180808
# 13    GA           Atlanta    20180314
# 14    GA       Thomasville    20180815
# 15    CA          Woodland    20180307
# 16    MA       Springfield    20180110
# 17    IL             Alsip    20180808
# 18    KS            Lenexa    20180314
# 19    WI           Madison    20181226
# 20    PA         Allentown    20181128
# 21    WI           Kenosha    20180523
# 22    MN       Minneapolis    20180509
# ...

# %%
#year 2017 API Request for product recalls
url_17 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20170101+TO+20171231]&limit=99"
firms_17 = requests.get(url_17).json()
firms_17
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 3187}},
#  'results': [{'country': 'United States',
#    'city': 'Elk Grove Village',
#    'reason_for_recall': 'Foreign Matter (a 1/8  long x 8mm, white & blue strand) found on product.',
#    'address_1': '412 E Devon Ave',
#    'address_2': '',
#    'code_info': 'Products manufactured on 11/01/2017, with Sell by Date: 11/07/2017.',
#    'product_quantity': 'Total 4,041 boxes and containers',
#    'center_classification_date': '20171208',
#    'distribution_pattern': 'GA and SC.',
#    'state': 'IL',
# ...

# %%
df_17 = pd.DataFrame(firms_17["results"])
#csv_name_17 = "FDA_Recall_2017.csv"
#df.to_csv(csv_name_17, index=False)

# %%
df_clean_17 = df_17[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_17
#csv_name_clean_17 = "FDA_Recall_clean_2017.csv"
#df_clean_17.to_csv(csv_name_clean_17)
# Out:
#    state                city report_date  \
# 0     IL   Elk Grove Village    20171213
# 1     FL               Miami    20170104
# 2     NH          Portsmouth    20170823
# 3     PA           Lewistown    20170426
# 4     FL               Miami    20170104
# 5     IN        Indianapolis    20170118
# 6     MO              Osborn    20170830
# 7     PR             Morovis    20170329
# 8     MI             Jackson    20170426
# 9     VA             Elkwood    20170621
# 10    IL             Chicago    20170726
# 11    PA           Lewistown    20170426
# 12    IN        Indianapolis    20170118
# 13    TX               Plano    20170705
# 14    SC           Rock Hill    20170719
# 15    CA            Alhambra    20170426
# 16    PA           Lewistown    20170426
# 17    PA          Royersford    20170802
# 18    NY              Walton    20170412
# 19    FL          Palm Coast    20170802
# 20    PA           Lewistown    20170426
# 21    MA              Boston    20170802
# ...

# %%
#year 2016 API Request for product recalls
url_16 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20160101+TO+20161231]&limit=99"

firms_16 = requests.get(url_16).json()
firms_16
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 3012}},
#  'results': [{'country': 'United States',
#    'city': 'Woodridge',
#    'reason_for_recall': 'Airbrush color has the potential to be contaminated with mold, yeast or bacteria.',
#    'address_1': '2240 75th St',
#    'address_2': '',
#    'code_info': 'Lots: 701-2418; 2201-2583',
#    'product_quantity': '14,595 bottles',
#    'center_classification_date': '20161026',
#    'distribution_pattern': 'Nationwide in U.S. and Canada',
#    'state': 'IL',
# ...

# %%
df_16 = pd.DataFrame(firms_16["results"])
df_16
#csv_name_16 = "FDA_Recall_2016.csv"
#df.to_csv(csv_name_16, index=False)
# Out:
#                        address_1 address_2 center_classification_date  \
# 0                   2240 75th St                             20161026
# 1              903 N Broadway St                             20160930
# 2                   550 Bowie St                             20160928
# 3                901 E Levin Ave                             20161208
# 4                 5423 N Lake Dr                             20161018
# 5            6511 Golden Gate Dr                             20160203
# 6   100 Redwood Shores Pkwy Fl 2                             20160618
# 7              903 N Broadway St                             20160930
# 8        131 Frost Commerical Dr                             20160104
# 9                165-35 145th Dr                             20161028
# 10                25 Research Dr                             20160406
# 11         1375 Avenue S Ste 300                             20160823
# ...

# %%
df_clean_16 = df_16[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_16
#csv_name_clean_16 = "FDA_Recall_clean_2016.csv"
#df_clean_16.to_csv(csv_name_clean_16)
# Out:
#    state           city report_date  \
# 0     IL      Woodridge    20161102
# 1     KS      Louisburg    20161012
# 2     TX         Austin    20161005
# 3     CA         Tulare    20161214
# 4     GA      Lake City    20161026
# 5     CA         Dublin    20160210
# 6     CA   Redwood City    20160629
# 7     KS      Louisburg    20161012
# 8     LA    West Monroe    20160113
# 9     NY        Jamaica    20161109
# 10    MA    Westborough    20160413
# 11    TX  Grand Prairie    20160831
# 12    LA    West Monroe    20160113
# 13    MN         Chaska    20161026
# 14    FL          Miami    20160224
# 15    CA    Bakersfield    20160727
# 16    CA         Vernon    20161228
# 17    CA    Los Angeles    20160928
# 18    NY       Brooklyn    20160413
# 19    NJ     Belleville    20161214
# 20    TN          Bells    20160713
# 21    CA   Solana Beach    20160921
# 22    WA          Pasco    20160803
# 23    CA       Monterey    20160309
# 24    WA          Pasco    20160824
# ...

# %%
#year 2015 API Request for product recalls
url_15 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20150101+TO+20151231]&limit=99"
firms_15 = requests.get(url_15).json()
firms_15
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 2835}},
#  'results': [{'country': 'United States',
#    'city': 'City Of Industry',
#    'reason_for_recall': 'Health One Pharmaceuticals is recalling dietary supplements due to significant violations of the cGMP regulations for dietary supplements.',
#    'address_1': '13260 Temple Ave',
#    'address_2': '',
#    'code_info': '8851',
#    'product_quantity': '5013 units',
#    'center_classification_date': '20150330',
# ...

# %%
df_15 = pd.DataFrame(firms_15["results"])
df_15
#csv_name_15 = "FDA_Recall_2015.csv"
#df.to_csv(csv_name_15, index=False)
# Out:
#                                  address_1 address_2  \
# 0                         13260 Temple Ave
# 1                         960 Franklin Ave
# 2                           1011 S Acme Rd
# 3                   5415 E High St Ste 350
# 4                   10220 Nw Ambassador Dr
# 5                        1002B Sunburst Dr
# 6                   380 Knollwood St Ste M
# 7                             631 Water St
# 8                     320 Commerce Park Rd
# 9                        21106 86th Ave SE
# 10                            180 State St
# 11                      6411 N Western Ave
# 12                            631 Water St
# 13                        4102 Bergen Tpke
# 14                        13260 Temple Ave
# 15                       1002B Sunburst Dr
# 16                       2401 W Almond Ave
# 17                     1101 S Blue Bell Rd
# 18                         601 Madison Ave
# 19                       1703 N Randall Rd
# ...

# %%
df_clean_15 = df_15[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_15
#csv_name_clean_15 = "FDA_Recall_clean_2015.csv"
#df_clean_15.to_csv(csv_name_clean_15)
# Out:
#    state              city report_date  \
# 0     CA  City Of Industry    20150408
# 1     NY          Brooklyn    20150311
# 2     TX       San Antonio    20150408
# 3     AZ           Phoenix    20150826
# 4     MO       Kansas City    20150805
# 5     NC         Goldsboro    20150204
# 6     NC     Winston Salem    20151111
# 7     WA     Port Townsend    20150304
# 8     RI   North Kingstown    20151111
# 9     WA         Snohomish    20150708
# 10    NY         Brockport    20151118
# 11    IL           Chicago    20150715
# 12    WA     Port Townsend    20150304
# 13    NJ      North Bergen    20150401
# 14    CA  City Of Industry    20150408
# 15    NC         Goldsboro    20150204
# 16    CA            Madera    20151125
# 17    TX           Brenham    20150701
# 18    WI          Sullivan    20150506
# 19    IL             Elgin    20150204
# 20    NJ           Neptune    20150520
# 21    CA          Monterey    20151125
# 22    TX           Brenham    20150701
# ...

# %%
#year 2014 API Request for product recalls
url_14 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20140101+TO+20141231]&limit=99"
firms_14 = requests.get(url_14).json()
firms_14
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 2259}},
#  'results': [{'country': 'United States',
#    'city': 'Austin',
#    'reason_for_recall': 'The product has the potential to be contaminated with Listeria monocytogenes.',
#    'address_1': '550 Bowie St',
#    'address_2': '',
#    'code_info': 'Sold between June 1 and July 21, 2014 at Whole Foods Stores',
#    'product_quantity': 'Unknown',
#    'center_classification_date': '20141209',
#    'distribution_pattern': 'All states where Whole Foods Market stores are located except Florida, Washington, and Oregon.',
# ...

# %%
df_14 = pd.DataFrame(firms_14["results"])
df_14
#csv_name_14 = "FDA_Recall_2014.csv"
#df.to_csv(csv_name_14, index=False)
# Out:
#                         address_1 address_2 center_classification_date  \
# 0                    550 Bowie St                             20141209
# 1                  5766 2nd St NE                             20140721
# 2               7030 County Rd 25                             20140107
# 3              913 Bridgeton Ave.                             20140307
# 4              2221 Frankfort Ave                             20140709
# 5           15570 SW Jenkins Road                             20131224
# 6                13439 NW 19 LANE                             20141202
# 7                   550 Oliver Dr                             20141030
# 8                   550 Oliver Dr                             20141030
# 9                   2640 Roff Ave                             20140328
# 10                  550 Oliver Dr                             20141030
# 11                88 First Street                             20140311
# ...

# %%
df_clean_14 = df_14[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_14
#csv_name_clean_14 = "FDA_Recall_clean_2014.csv"
#df_clean_14.to_csv(csv_name_clean_14)
# Out:
#    state                city report_date  \
# 0     TX              Austin    20141217
# 1     DC          Washington    20140730
# 2     CA              Orland    20140115
# 3     NJ           Rosenhayn    20140319
# 4     KY          Louisville    20140716
# 5     OR           Beaverton    20140101
# 6     FL               Miami    20141210
# 7     MI                Troy    20141105
# 8     MI                Troy    20141105
# 9     GA               Macon    20140409
# 10    MI                Troy    20141105
# 11    NJ             Passaic    20140319
# 12    OR           Beaverton    20140101
# 13    WA                Kent    20140409
# 14    FL               Miami    20141029
# 15    MA           Cambridge    20141231
# 16    IL             Chicago    20140723
# 17    MI                Troy    20141105
# 18    NY         Farmingdale    20140108
# 19    HI            Honolulu    20140226
# 20    AK              Kodiak    20140625
# 21    SC  Hilton Head Island    20141210
# ...

# %%
#year 2013 API Request for product recalls
url_13 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20130101+TO+20131231]&limit=99"
firms_13 = requests.get(url_13).json()
firms_13
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 2108}},
#  'results': [{'country': 'United States',
#    'city': 'Austin',
#    'reason_for_recall': "Whole Foods Market announces that it is recalling &amp;amp;amp;amp;amp;amp;amp;amp;quot;Kenny's Farmhouse Cheese KY BL&amp;amp;amp;amp;amp;amp;amp;amp;quot; sold in its Louisville, KY store and &amp;amp;amp;amp;amp;amp;amp;amp;quot;Blue Kentucky Rose Kenny's&amp;amp;amp;amp;amp;amp;amp;amp;quot; cheese sold in its Nashville, TN store. These cheeses are being recalled because they have the potentia",
# ...

# %%
df_13 = pd.DataFrame(firms_13["results"])
df_13
#csv_name_13 = "FDA_Recall_2013.csv"
#df.to_csv(csv_name_13, index=False)
# Out:
#                          address_1               address_2  \
# 0         601 N Lamar Blvd Ste 300
# 1                   726 S 12th St.
# 2                   726 S 12th St.
# 3                   726 S 12th St.
# 4                  1904 Chamisa St
# 5              10439 Double R Blvd
# 6       M-1066, Calle B, Bo Palmas  Palmas Industrial Park
# 7             22540 Russell Avenue
# 8               2929 Walker Ave Nw
# 9                   726 S 12th St.
# 10                  16231 Elza Dr.
# 11            601 North Stolle Ave
# 12                  950 W 190th St
# 13                  726 S 12th St.
# 14                  726 S 12th St.
# 15                  100 Pulaski St
# 16      3300 Publix Corporate Pkwy
# 17      3300 Publix Corporate Pkwy
# 18                  100 Pulaski St
# 19                 4014 15th Ave N
# 20   9655 Granite Ridge Dr Ste 100
# 21              o-197 Steele st NW
# 22                  726 S 12th St.
# 23                 4014 15th Ave N
# ...

# %%
df_clean_13 = df_13[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_13
#csv_name_clean_13 = "FDA_Recall_clean_2013.csv"
#df_clean_13.to_csv(csv_name_clean_13)
# Out:
#    state              city report_date  \
# 0     TX            Austin    20130116
# 1     WI         Milwaukee    20131225
# 2     WI         Milwaukee    20131211
# 3     WI         Milwaukee    20131225
# 4     NM          Santa Fe    20131225
# 5     NV              Reno    20131127
# 6     PR            Catano    20130904
# 7     CA   South Dos Palos    20130306
# 8     MI      Grand Rapids    20130605
# 9     WI         Milwaukee    20131211
# 10    CA  Hacienda Heights    20131002
# 11    OH            Sidney    20130724
# 12    CA          Torrance    20130313
# 13    WI         Milwaukee    20131225
# 14    WI         Milwaukee    20131211
# 15    NJ           Bayonne    20130522
# 16    FL          Lakeland    20130320
# 17    FL          Lakeland    20130320
# 18    NJ           Bayonne    20131225
# 19    ND             Fargo    20130320
# 20    CA         San Diego    20130410
# 21    MI      Grand Rapids    20130612
# 22    WI         Milwaukee    20131225
# ...

# %%
#year 2012 API Request for product recalls
url_12 = "https://api.fda.gov/food/enforcement.json?search=report_date:[20120101+TO+20121231]&limit=99"
firms_12 = requests.get(url_12).json()
firms_12
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2019-04-20',
#   'results': {'skip': 0, 'limit': 99, 'total': 1916}},
#  'results': [{'country': 'United States',
#    'city': 'Medford',
#    'reason_for_recall': 'Product received from supplier is being recalled due to the potential to be contaminated with Salmonella',
#    'address_1': '2500 S Pacific Hwy',
#    'address_2': '',
# ...

# %%
df_12 = pd.DataFrame(firms_12["results"])
df_12
#csv_name_12 = "FDA_Recall_2012.csv"
#df.to_csv(csv_name_12, index=False)
# Out:
#                          address_1           address_2  \
# 0               2500 S Pacific Hwy
# 1                     170 Avenue L
# 2   18 Bunker Hill Industrial Park
# 3                8100 Radcliffe St
# 4                  8425 Carbide Ct
# 5          8901 E Pima Center Pkwy           Suite 215
# 6              42593 US Highway 70
# 7                   1147 Benson St
# 8                   726 S 12th St.
# 9              42593 US Highway 70
# 10         360 South Van Brunt St.
# 11                  463 44th St SE
# 12               23682 Clawiter Rd
# 13                  726 S 12th St.
# 14             42593 US Highway 70
# 15              89 Tompkins Street
# 16                   7989 Arndt Rd
# 17                   1037 State St
# 18                 4401 Foxdale St
# 19                  1531 W Main St
# 20                 8425 Carbide Ct
# 21          1 King And Prince Blvd
# 22             42593 US Highway 70
# 23                  726 S 12th St.
# ...

# %%
df_clean_12 = df_12[['state', 'city', 'report_date', 'product_description', 'product_quantity', 'reason_for_recall', 'recalling_firm', 'recall_number']]
df_clean_12
#csv_name_clean_12 = "FDA_Recall_clean_2012.csv"
#df_clean_12.to_csv(csv_name_clean_12)
# Out:
#    state                   city report_date  \
# 0     OR                Medford    20121107
# 1     NJ                 Newark    20121017
# 2     MA                 Boston    20120905
# 3     MI                Detroit    20120711
# 4     CA             Sacramento    20120815
# 5     AZ             Scottsdale    20120801
# 6     NM               Portales    20121031
# 7     WI            River Falls    20120718
# 8     WI              Milwaukee    20120919
# 9     NM               Portales    20121031
# 10    NJ              Englewood    20120711
# 11    MI           Grand Rapids    20121024
# 12    CA                Hayward    20121212
# 13    WI              Milwaukee    20120919
# 14    NM               Portales    20121031
# 15    NY                Spencer    20120620
# 16    WI           Oconto Falls    20121017
# 17    IL                Chester    20121128
# 18    CA              Irwindale    20121003
# 19    KY             Louisville    20121226
# ...

# %%
frames = [df_clean_12, df_clean_13, df_clean_14, df_clean_15, df_clean_16, df_clean_17, df_clean_18, df_clean_19]
result = pd.concat(frames, )
result = result.reset_index(drop=True)
result= result.rename(columns={"recalling_firm": "brands"})
result
# Out:
#     state             city report_date  \
# 0      OR          Medford    20121107
# 1      NJ           Newark    20121017
# 2      MA           Boston    20120905
# 3      MI          Detroit    20120711
# 4      CA       Sacramento    20120815
# 5      AZ       Scottsdale    20120801
# 6      NM         Portales    20121031
# 7      WI      River Falls    20120718
# 8      WI        Milwaukee    20120919
# 9      NM         Portales    20121031
# 10     NJ        Englewood    20120711
# 11     MI     Grand Rapids    20121024
# 12     CA          Hayward    20121212
# 13     WI        Milwaukee    20120919
# 14     NM         Portales    20121031
# 15     NY          Spencer    20120620
# 16     WI     Oconto Falls    20121017
# 17     IL          Chester    20121128
# 18     CA        Irwindale    20121003
# 19     KY       Louisville    20121226
# 20     CA       Sacramento    20120815
# 21     GA        Brunswick    20120620
# 22     NM         Portales    20121031
# ...

# %%
import pandas as pd
from pandas.io import sql
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://USERNAME:PASSWORD3@localhost/fda_db')
with engine.connect() as con, con.begin():
    result.to_sql(con=con, name='fda_db', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-8057bf2e6b81> in <module>
#       2 from pandas.io import sql
#       3 from sqlalchemy import create_engine
# ----> 4 engine = create_engine('mysql+pymysql://USERNAME:PASSWORD3@localhost/fda_db')
#       5 with engine.connect() as con, con.begin():
#       6     result.to_sql(con=con, name='fda_db', if_exists='replace')
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     423     strategy = kwargs.pop('strategy', default_strategy)
#     424     strategy = strategies.strategies[strategy]
# --> 425     return strategy.create(*args, **kwargs)
#     426
#     427
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      79                 if k in kwargs:
#      80                     dbapi_args[k] = pop_kwarg(k)
# ...

# %%
data_csv = "ingredients.csv"
ingredients_summary = pd.read_csv(data_csv)
ingredients_summary

# %%
with engine.connect() as con, con.begin():
    ingredients_summary.to_sql(con=con, name='fda_db_2', if_exists='replace')

# %%
adverse_reaction_csv = "adverse_reactions.csv"
adverse_reaction = pd.read_csv(adverse_reaction_csv)
adverse_reaction
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# 5            65345              1/1/2004           12/21/2003
# 6            65350              1/1/2004                  NaN
# 7            65353              1/2/2004            12/1/2003
# 8            65353              1/2/2004            12/1/2003
# 9            65354              1/2/2004                  NaN
# 10           65355              1/2/2004           10/27/2003
# 11           65356              1/2/2004           10/27/2003
# 12           65357              1/2/2004           10/27/2003
# 13           65379              1/3/2004            11/5/2003
# ...

# %%
final_reactions = adverse_reaction[['brands','PRI_FDA Industry Name', 'AEC_One Row Outcomes', 'RA_CAERS Created Date']]
final_reactions.head()
# Out:
#                                               brands  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...
# 3                         ENFAMIL LIPIL BABY FORMULA
# 4                         ENFIMIL LIPIL BABY FORMULA
#
#          PRI_FDA Industry Name  \
# 0  Bakery Prod/Dough/Mix/Icing
# 1  Bakery Prod/Dough/Mix/Icing
# 2               Ice Cream Prod
# 3               Baby Food Prod
# 4               Baby Food Prod
#
#                                 AEC_One Row Outcomes RA_CAERS Created Date
# 0  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...              1/1/2004
# 1  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...              1/1/2004
# 2                                      VISITED AN ER              1/1/2004
# 3                      NON-SERIOUS INJURIES/ ILLNESS              1/1/2004
# 4                     VISITED A HEALTH CARE PROVIDER              1/1/2004

# %%
updated_reaction_df = final_reactions.rename(columns={"brands": "brand","PRI_FDA Industry Name":"Industry", "AEC_One Row Outcomes":"Adverse Reaction Outcome", "RA_CAERS Created Date": "report_date"})
updated_reaction_df.head()
# Out:
#                                                brand  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...
# 3                         ENFAMIL LIPIL BABY FORMULA
# 4                         ENFIMIL LIPIL BABY FORMULA
#
#                       Industry  \
# 0  Bakery Prod/Dough/Mix/Icing
# 1  Bakery Prod/Dough/Mix/Icing
# 2               Ice Cream Prod
# 3               Baby Food Prod
# 4               Baby Food Prod
#
#                             Adverse Reaction Outcome report_date
# 0  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...    1/1/2004
# 1  VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...    1/1/2004
# 2                                      VISITED AN ER    1/1/2004
# 3                      NON-SERIOUS INJURIES/ ILLNESS    1/1/2004
# 4                     VISITED A HEALTH CARE PROVIDER    1/1/2004

# %%
with engine.connect() as con, con.begin():
    adverse_reaction.to_sql(con=con, name='reaction_db', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c1f2c761b16a> in <module>
# ----> 1 with engine.connect() as con, con.begin():
#       2     adverse_reaction.to_sql(con=con, name='reaction_db', if_exists='replace')
#       3
#       4
#
# NameError: name 'engine' is not defined
